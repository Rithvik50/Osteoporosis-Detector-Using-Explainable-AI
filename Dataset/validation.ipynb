# %%
import pandas as pd

# %%
df = pd.read_csv('final_cleaned_dataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10500 entries, 0 to 10499
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          10500 non-null  int64
#  1   Age                             10500 non-null  int64
#  2   Menopause Age                   10500 non-null  int64
#  3   Height                          10500 non-null  float64
#  4   Weight                          10500 non-null  float64
#  5   Smoker                          10500 non-null  int64
#  6   Alcoholic                       10500 non-null  int64
#  7   Diabetic                        10500 non-null  int64
#  8   Hypothyroidism                  10500 non-null  int64
#  9   Estrogen Use                    10500 non-null  int64
#  10  History of Fracture             10500 non-null  int64
#  11  Dialysis                        10500 non-null  int64
# ...

# %%
df.describe(include='all')
# Out:
#              Gender           Age  Menopause Age        Height        Weight  \
# count  10500.000000  10500.000000   10500.000000  10500.000000  10500.000000
# mean       0.654476     62.759429      28.038476    166.884876     68.833857
# std        0.475561     15.681953      24.875697     10.517421     17.716634
# min        0.000000     20.000000       0.000000    145.000000     31.300000
# 25%        0.000000     53.000000       0.000000    159.400000     55.900000
# 50%        1.000000     64.000000      45.000000    166.200000     66.900000
# 75%        1.000000     74.000000      50.000000    173.800000     79.800000
# max        1.000000     95.000000      58.000000    200.000000    152.500000
#
#             Smoker     Alcoholic      Diabetic  Hypothyroidism  Estrogen Use  \
# count  10500.00000  10500.000000  10500.000000    10500.000000  10500.000000
# mean       0.60800      0.523524      0.506952        0.461143      0.087810
# ...

# %%
df.isnull().sum()
# Out:
# Gender                            0
# Age                               0
# Menopause Age                     0
# Height                            0
# Weight                            0
# Smoker                            0
# Alcoholic                         0
# Diabetic                          0
# Hypothyroidism                    0
# Estrogen Use                      0
# History of Fracture               0
# Dialysis                          0
# Family History of Osteoporosis    0
# T-score Value                     0
# Z-Score Value                     0
# BMI                               0
# Diagnosis                         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[(df["Gender"] == 0) & (df["Menopause Age"] != 0)]
# Out:
# Empty DataFrame
# Columns: [Gender, Age, Menopause Age, Height, Weight, Smoker, Alcoholic, Diabetic, Hypothyroidism, Estrogen Use, History of Fracture, Dialysis, Family History of Osteoporosis, T-score Value, Z-Score Value, BMI, Diagnosis]
# Index: []

# %%
df[(df["Gender"] == 1) & (df["Age"] > 50) & (df["Menopause Age"] == 0)]
# Out:
# Empty DataFrame
# Columns: [Gender, Age, Menopause Age, Height, Weight, Smoker, Alcoholic, Diabetic, Hypothyroidism, Estrogen Use, History of Fracture, Dialysis, Family History of Osteoporosis, T-score Value, Z-Score Value, BMI, Diagnosis]
# Index: []

# %%
df[(df["Gender"] == 1) & (df["Age"] >= 45) & (df["Menopause Age"] == 0)]
# Out:
#        Gender  Age  Menopause Age  Height  Weight  Smoker  Alcoholic  \
# 110         1   45              0   160.7    54.0       0          1
# 114         1   49              0   165.2    67.7       0          1
# 174         1   46              0   162.7    49.4       0          0
# 192         1   45              0   173.3    46.3       0          1
# 292         1   45              0   149.6    46.0       0          1
# ...       ...  ...            ...     ...     ...     ...        ...
# 8644        1   45              0   146.2    57.1       1          0
# 9785        1   45              0   148.4    46.7       1          1
# 10204       1   45              0   171.7    62.6       1          0
# 10313       1   45              0   160.7    51.8       1          0
# 10374       1   45              0   168.5    89.0       1          1
#
#        Diabetic  Hypothyroidism  Estrogen Use  History of Fracture  Dialysis  \
# ...

# %%
df[(df["Gender"] == 1) & (df["Menopause Age"] > df["Age"])]
# Out:
# Empty DataFrame
# Columns: [Gender, Age, Menopause Age, Height, Weight, Smoker, Alcoholic, Diabetic, Hypothyroidism, Estrogen Use, History of Fracture, Dialysis, Family History of Osteoporosis, T-score Value, Z-Score Value, BMI, Diagnosis, BMI_zscore]
# Index: []

# %%
df[(df["BMI"] < 10) | (df["BMI"] > 60)]
# Out:
# Empty DataFrame
# Columns: [Gender, Age, Menopause Age, Height, Weight, Smoker, Alcoholic, Diabetic, Hypothyroidism, Estrogen Use, History of Fracture, Dialysis, Family History of Osteoporosis, T-score Value, Z-Score Value, BMI, Diagnosis]
# Index: []

# %%
df[(df["Age"] < 10) | (df["Age"] > 120)]
# Out:
# Empty DataFrame
# Columns: [Gender, Age, Menopause Age, Height, Weight, Smoker, Alcoholic, Diabetic, Hypothyroidism, Estrogen Use, History of Fracture, Dialysis, Family History of Osteoporosis, T-score Value, Z-Score Value, BMI, Diagnosis]
# Index: []

# %%
# Diagnosis vs T-score check (WHO definitions)
df[((df["T-score Value"] >= -1) & (df["Diagnosis"] != 0)) |
   ((df["T-score Value"] < -1) & (df["T-score Value"] > -2.5) & (df["Diagnosis"] != 1)) |
   ((df["T-score Value"] <= -2.5) & (df["Diagnosis"] != 2))]
# Out:
# Empty DataFrame
# Columns: [Gender, Age, Menopause Age, Height, Weight, Smoker, Alcoholic, Diabetic, Hypothyroidism, Estrogen Use, History of Fracture, Dialysis, Family History of Osteoporosis, T-score Value, Z-Score Value, BMI, Diagnosis, BMI_zscore]
# Index: []

# %%
# Class balance
df["Diagnosis"].value_counts()

# Histograms (for Age, BMI, T-score)
df["Age"].hist(bins=30)
df["BMI"].hist(bins=30)
df["T-score Value"].hist(bins=30)
# Out:
# <Axes: >

# %% [markdown]
# Dataset ready for training.
